# %%
import polars as pl

# %%
df = pl.LazyFrame({
    "name":["Batman", "Gandalf"],
    "age": [35, 500]
})

# %%
df.filter(pl.col("age")<100).collect()
# Out:
# shape: (1, 2)
# ┌────────┬─────┐
# │ name   ┆ age │
# │ ---    ┆ --- │
# │ str    ┆ i64 │
# ╞════════╪═════╡
# │ Batman ┆ 35  │
# └────────┴─────┘
